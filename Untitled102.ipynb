# %%
# !pip install opendatasets

# %%
import opendatasets as opd
opd.download("https://www.kaggle.com/datasets/ammaraahmad/top-10-machine-learning-datasets")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: ravipratap1303
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/ammaraahmad/top-10-machine-learning-datasets
# ...
# 100%|██████████| 883k/883k [00:00<00:00, 105MB/s]

# %%
import pandas as pd
data= pd.read_csv("")
data.head()/content/top-10-machine-learning-datasets/cars_clus.csv
# Out:
#   manufact    model   sales  resale  type  price  engine_s  horsepow  \
# 0    Acura  Integra  16.919  16.360     0  21.50       1.8       140
# 1    Acura       TL  39.384  19.875     0  28.40       3.2       225
# 2    Acura       RL   8.588  29.725     0  42.00       3.5       210
# 3     Audi       A4  20.397  22.255     0  23.99       1.8       150
# 4     Audi       A6  18.780  23.555     0  33.95       2.8       200
#
#    wheelbas  width  length  curb_wgt  fuel_cap   mpg  lnsales  partition
# 0     101.2   67.3   172.4     2.639      13.2  28.0    2.828          0
# 1     108.1   70.3   192.9     3.517      17.2  25.0    3.673          0
# 2     114.6   71.4   196.6     3.850      18.0  22.0    2.150          0
# 3     102.6   68.2   178.0     2.998      16.4  27.0    3.015          0
# 4     108.7   76.1   192.0     3.561      18.5  22.0    2.933          0

# %%
data.drop(['manufact','model','type','partition'],axis=1,inplace= True)

# %%
data.head()
# Out:
#     sales  resale  price  engine_s  horsepow  wheelbas  width  length  \
# 0  16.919  16.360  21.50       1.8       140     101.2   67.3   172.4
# 1  39.384  19.875  28.40       3.2       225     108.1   70.3   192.9
# 2   8.588  29.725  42.00       3.5       210     114.6   71.4   196.6
# 3  20.397  22.255  23.99       1.8       150     102.6   68.2   178.0
# 4  18.780  23.555  33.95       2.8       200     108.7   76.1   192.0
#
#    curb_wgt  fuel_cap   mpg  lnsales
# 0     2.639      13.2  28.0    2.828
# 1     3.517      17.2  25.0    3.673
# 2     3.850      18.0  22.0    2.150
# 3     2.998      16.4  27.0    3.015
# 4     3.561      18.5  22.0    2.933

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sales     117 non-null    float64
#  1   resale    117 non-null    float64
#  2   price     117 non-null    float64
#  3   engine_s  117 non-null    float64
#  4   horsepow  117 non-null    int64
#  5   wheelbas  117 non-null    float64
#  6   width     117 non-null    float64
#  7   length    117 non-null    float64
#  8   curb_wgt  117 non-null    float64
#  9   fuel_cap  117 non-null    float64
#  10  mpg       117 non-null    float64
#  11  lnsales   117 non-null    float64
# dtypes: float64(11), int64(1)
# memory usage: 11.1 KB

# %%
data.columns
# Out:
# Index(['sales', 'resale', 'price', 'engine_s', 'horsepow', 'wheelbas', 'width',
#        'length', 'curb_wgt', 'fuel_cap', 'mpg', 'lnsales'],
#       dtype='object')

# %%
x= data[['resale', 'price', 'engine_s', 'horsepow', 'wheelbas', 'width',
       'length', 'curb_wgt', 'fuel_cap', 'mpg', 'lnsales']]

# %%
y= data['sales']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()
model.fit(x_train,y_train)
y_pred= model.predict(x_test)
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.40459213922654624

# %%
from sklearn.tree import DecisionTreeRegressor
model1= DecisionTreeRegressor()
model1.fit(x_train,y_train)
y_pred1= model1.predict(x_test)
from sklearn.metrics import r2_score
r2_score(y_test,y_pred1)
# Out:
# -0.8325422289553175

# %%
from sklearn.svm import SVR
model2= SVR()
model2.fit(x_train,y_train)
y_pred2= model2.predict(x_test)
from sklearn.metrics import r2_score
r2_score(y_test,y_pred2)
# Out:
# -0.29430271832485944

# %%
from sklearn.ensemble import RandomForestRegressor
model3= RandomForestRegressor()
model3.fit(x_train,y_train)
y_pred3= model3.predict(x_test)
from sklearn.metrics import r2_score
r2_score(y_test,y_pred3)
# Out:
# 0.9796097357269946

# %%
# !pip install scikit-learn==1.5.1
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 27.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.3.2
#     Uninstalling scikit-learn-1.3.2:
#       Successfully uninstalled scikit-learn-1.3.2
# ...

# %%
x.head(2)
# Out:
#    resale  price  engine_s  horsepow  wheelbas  width  length  curb_wgt  \
# 0  16.360   21.5       1.8       140     101.2   67.3   172.4     2.639
# 1  19.875   28.4       3.2       225     108.1   70.3   192.9     3.517
#
#    fuel_cap   mpg  lnsales
# 0      13.2  28.0    2.828
# 1      17.2  25.0    3.673

# %%
user_data= [[16.360,21.5,1.8,130,100,65,170,2.45,13,28,2.6]]
Prediction= model3.predict(user_data)
print(Prediction)
# Out:
# [13.81657]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   should set `reset=False`.

# %%
import pickle
pickle.dump(model3,open('model.pkl','wb'))
